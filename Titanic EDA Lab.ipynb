# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("C:\\Users\\JJ\Documents\\Spring2015_DataScienceEssentials\\Week_3\\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# # EDA , exploratory data analysis
#
# <li>For each variable (except name), need to find out
#
# 1.  Is the variable categorical or continuous
#
# 2.  Are there missing values?
#
# 3. Min, Max, Mean, and Standard Deviation of the continuous variables.
#
# 4. Histograms describing the distribution of the variable.
#
# 5.  EDA should be completed for these fields:  'PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', and 'Embarked'

# %%
# see the min max mean sd etc for the continuous variables in the data frame
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### EDA for 'PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', and 'Embarked'
# <ul>1.  Is the variable categorical or continuous
# <br><b>(please see .value_counts() results below)</b>
# <br><b>PassengerId: It is continuous starting from 1 to 891 with a step of 1. </b>
# <br><b>Survived: It is categorical with either 1 or 0 as classes. </b>
# <br><b>Pclass: It is categorical with either 1, 2 and 3 as classes. </b>
# <br><b>Sex: It is categorical with either male or female as classes. </b>
# <br><b>Age: It is continuous.</b>
# <br><b>SibSp (Number of Siblings/Spouses Aboard): It is continuous.</b>
# <br><b>Parch (Number of Parents/Children Aboard): It is continuous.</b>
# <br><b>Ticket: It is categorical</b>
# <br><b>Fare: It is continuous.</b>
# <br><b>Cabin: It is categorical.</b>
# <br><b>Embarked: It is categorical.</b>

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# ...
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Length: 891, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# dtype: int64

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# dtype: int64

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# dtype: int64

# %%
df.Age.value_counts()
# Out:
# 24    30
# 22    27
# 18    26
# 28    25
# 30    25
# 19    25
# 21    24
# 25    23
# 36    22
# 29    20
# 32    18
# 35    18
# 27    18
# 26    18
# 16    17
# ...
# 53.00    1
# 70.50    1
# 14.50    1
# 0.92     1
# 74.00    1
# 36.50    1
# 80.00    1
# 12.00    1
# 55.50    1
# 34.50    1
# 24.50    1
# 66.00    1
# 23.50    1
# 0.67     1
# 20.50    1
# Length: 88, dtype: int64

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# dtype: int64

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# dtype: int64

# %%
df.Ticket.value_counts()
# Out:
# CA. 2343        7
# 347082          7
# 1601            7
# 347088          6
# CA 2144         6
# 3101295         6
# 382652          5
# S.O.C. 14879    5
# PC 17757        4
# 4133            4
# LINE            4
# 349909          4
# 347077          4
# W./C. 6608      4
# 113760          4
# ...
# STON/O 2. 3101273    1
# 345777               1
# STON/O 2. 3101274    1
# STON/O 2. 3101275    1
# 113794               1
# 2649                 1
# 374887               1
# 349213               1
# 349210               1
# 349242               1
# 349216               1
# 112052               1
# 315088               1
# 349215               1
# W./C. 14258          1
# Length: 681, dtype: int64

# %%
df.Fare.value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
# 10.5000    24
# 7.9250     18
# 7.7750     16
# 7.2292     15
# 26.5500    15
# 0.0000     15
# 7.2500     13
# 7.8542     13
# 8.6625     13
# 7.2250     12
# ...
# 15.0000    1
# 28.7125    1
# 61.1750    1
# 6.2375     1
# 15.1000    1
# 39.4000    1
# 81.8583    1
# 61.9792    1
# 7.8000     1
# 22.0250    1
# 47.1000    1
# 13.4167    1
# 14.1083    1
# 15.5500    1
# 13.7917    1
# Length: 248, dtype: int64

# %%
df.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# D                  3
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# B57 B59 B63 B66    2
# C68                2
# B58 B60            2
# E121               2
# D20                2
# E8                 2
# E44                2
# ...
# E50    1
# A14    1
# C91    1
# A16    1
# B38    1
# B39    1
# C95    1
# B78    1
# B79    1
# C99    1
# B37    1
# A19    1
# E12    1
# A7     1
# D15    1
# Length: 147, dtype: int64

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# dtype: int64

# %% [markdown]
# <ul>2.Are there missing values?
# <br><b>(please see the result for each variable below this block)</b>
# <br><b>PassengerId: No </b>
# <br><b>Survived: No </b>
# <br><b>Pclass: No </b>
# <br><b>Sex: No </b>
# <br><b>Age: Yes</b>
# <br><b>SibSp (Number of Siblings/Spouses Aboard): No </b>
# <br><b>Parch (Number of Parents/Children Aboard): No </b>
# <br><b>Ticket: No </b>
# <br><b>Fare: No </b>
# <br><b>Cabin: Yes </b>
# <br><b>Embarked: Yes </b>

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female   38      0      0  113572    80   B28      NaN
# 829  female   62      0      0  113572    80   B28      NaN

# %% [markdown]
# <ul>3. Min, Max, Mean, and Standard Deviation of the continuous variables?
# <br><b> (please see the results above from df.describe() )</b>
# <br><b>PassengerId: Min = 1.000000; Max = 891.000000; Mean = 446.000000; STD = 257.353842. </b>
#
# <br><b>Age: Min = 0.420000; Max = 80.000000; Mean = 29.699118; STD = 14.526497. </b>
#
# <br><b>SibSp (Number of Siblings/Spouses Aboard): Min = 0.000000; Max = 8.000000; Mean = 0.523008; STD = 1.102743. </b>
#
# <br><b>Parch (Number of Parents/Children Aboard): Min = 0.000000; Max = 6.000000; Mean = 0.381594; STD = 0.806057.</b>
#
# <br><b>Fare: Min = 0.000000; Max = 512.329200; Mean = 32.204208; STD = 49.693429. </b>

# %% [markdown]
# <ul>4. Histograms describing the distribution of the variable.
# <br><b>(please see the histogram for each variable below)</b>

# %%
df.PassengerId.hist(bins=900)

# %%
df.Survived.value_counts().plot(kind = 'barh')

# %%
df.Pclass.value_counts().plot(kind = 'barh')

# %%
df.Sex.value_counts().plot(kind = 'barh')

# %%
df.Age.hist(bins=50)

# %%
df.SibSp.hist(bins=10)

# %%
df.Parch.hist(bins=10)

# %%
df.Ticket.value_counts().plot(kind = 'bar')

# %%
df.Fare.hist(bins=8)

# %%
df.Cabin.value_counts().plot(kind = 'bar')

# %%
df.Embarked.value_counts().plot(kind = 'barh')
